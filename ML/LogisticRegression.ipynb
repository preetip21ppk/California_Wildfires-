# %%
# Import dependenices.
from sqlalchemy import create_engine
from sqlalchemy import join
from sqlalchemy.sql import select
import pandas as pd
import sys, os

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import plot_confusion_matrix
from sklearn import tree, preprocessing
import sklearn.ensemble as ske
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
scaled_data = StandardScaler()
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score


sys.path.append(os.path.abspath(os.path.join('..')))
from config import db_password
# !pip install psycopg2-binary
# Out:
# Requirement already satisfied: psycopg2-binary in c:\users\anupriya\anaconda3\envs\pythondata\lib\site-packages (2.9.1)

# %%
# Connect Pandas to SQL.
db_string = f"postgresql://postgres:{db_password}0@127.0.0.1:5432/wildfire_db"
engine = create_engine(db_string)

# %%
#Perfom inner join on fire_incidents, fire_locations and fire_impacts


query1 = "select fire_incidents.fire_started_date,fire_incidents.fire_extinguished_date, "\
         "fire_incidents.major_incident, fire_incidents.cause_description, "\
         "fire_incidents.archive_year, "\
         "fire_impacts.total_acres_burned,fire_impacts.injuries, "\
         "fire_impacts.fire_name, fire_impacts.structure_impacted, "\
         "fire_locations.minimum_temp, "\
         "fire_locations.maximum_temp, "\
         "fire_locations.average_temp, "\
         "fire_locations.wind_speed, " \
         "fire_locations.air_pressure, " \
         "fire_locations.precipitation, " \
         "fire_locations.county_name, " \
         "fire_locations.latitude, "\
         "fire_locations.longitude "\
         "FROM fire_incidents "\
         "JOIN fire_impacts ON fire_incidents.fire_name = fire_impacts.fire_name "\
         "JOIN fire_locations ON fire_incidents.fire_name = fire_locations.fire_name "


result = engine.execute(query1)

# %%
#Read query result into dataframe

impact_df = pd.DataFrame.from_records(result, columns=['fire_started_date','fire_extinguished_date','major_incident', 'cause_description','archive_year','total_acres_burned','injuries','fire_name','structure_impacted','minimum_temp','maximum_temp','average_temp','wind_speed','air_pressure','precipitation','county_name', 'latitude', 'longitude'])

# %%
impact_df.head()
# Out:
#   fire_started_date fire_extinguished_date  major_incident cause_description  \
# 0        2013-08-17             2013-09-06           False      Unidentified
# 1        2013-05-30             2013-06-08           False      Unidentified
# 2        2013-07-15             2013-07-30           False     Miscellaneous
# 3        2013-08-10             2013-08-30           False      Unidentified
# 4        2013-07-22             2013-09-24           False      Unidentified
#
#    archive_year  total_acres_burned  injuries        fire_name  \
# 0          2013              257314         0         Rim Fire
# 1          2013               30274         0  Powerhouse Fire
# 2          2013               27531         0    Mountain Fire
# 3          2013               27440         0    American Fire
# 4          2013               22992         0       Aspen Fire
#
#    structure_impacted minimum_temp maximum_temp average_temp wind_speed  \
# 0                   0         14.0         32.0         27.0        3.0
# 1                   0          9.0         34.0         27.0       18.0
# 2                   0         18.0         32.0         28.0        7.0
# 3                   0          6.0         26.0         20.0        4.0
# 4                   0         15.0         25.0         21.0        2.0
#
#   air_pressure precipitation  county_name   latitude    longitude
# 0       1015.0           0.0     Tuolumne     37.857     -120.086
# 1       1010.0           0.0  Los Angeles  34.585595  -118.423176
# 2       1010.0           0.0    Riverside    33.7095   -116.72885
# 3       1015.0           0.0       Placer      39.12      -120.65
# 4       1012.0           0.0       Fresno     37.279     -119.318

# %%
#Check data types
impact_df.dtypes
# Out:
# fire_started_date         object
# fire_extinguished_date    object
# major_incident              bool
# cause_description         object
# archive_year               int64
# total_acres_burned         int64
# injuries                   int64
# fire_name                 object
# structure_impacted         int64
# minimum_temp              object
# maximum_temp              object
# average_temp              object
# wind_speed                object
# air_pressure              object
# precipitation             object
# county_name               object
# latitude                  object
# longitude                 object
# dtype: object

# %%
#Rename columns
impact_df = impact_df.rename(columns={'minimum_temp':'minimum_temp(°C)',
                                      'maximum_temp':'maximum_temp(°C)',
                                      'average_temp':'average_temp(°C)',
                                      'wind_speed': 'wind_speed(km/hr)',
                                      'precipitation': 'precipitation(mm)'
                                     })


impact_df.head()
# Out:
#   fire_started_date fire_extinguished_date  major_incident cause_description  \
# 0        2013-08-17             2013-09-06           False      Unidentified
# 1        2013-05-30             2013-06-08           False      Unidentified
# 2        2013-07-15             2013-07-30           False     Miscellaneous
# 3        2013-08-10             2013-08-30           False      Unidentified
# 4        2013-07-22             2013-09-24           False      Unidentified
#
#    archive_year  total_acres_burned  injuries        fire_name  \
# 0          2013              257314         0         Rim Fire
# 1          2013               30274         0  Powerhouse Fire
# 2          2013               27531         0    Mountain Fire
# 3          2013               27440         0    American Fire
# 4          2013               22992         0       Aspen Fire
#
#    structure_impacted minimum_temp(°C) maximum_temp(°C) average_temp(°C)  \
# 0                   0             14.0             32.0             27.0
# 1                   0              9.0             34.0             27.0
# 2                   0             18.0             32.0             28.0
# 3                   0              6.0             26.0             20.0
# 4                   0             15.0             25.0             21.0
#
#   wind_speed(km/hr) air_pressure precipitation(mm)  county_name   latitude  \
# 0               3.0       1015.0               0.0     Tuolumne     37.857
# 1              18.0       1010.0               0.0  Los Angeles  34.585595
# 2               7.0       1010.0               0.0    Riverside    33.7095
# 3               4.0       1015.0               0.0       Placer      39.12
# 4               2.0       1012.0               0.0       Fresno     37.279
#
#      longitude
# 0     -120.086
# 1  -118.423176
# 2   -116.72885
# 3      -120.65
# 4     -119.318

# %%
#Converting the features to float data type
impact_df['maximum_temp(°C)'] = impact_df['maximum_temp(°C)'].astype('float64')
impact_df['wind_speed(km/hr)'] = impact_df['wind_speed(km/hr)'].astype('float64')
impact_df['precipitation(mm)'] = impact_df['precipitation(mm)'].astype('float64')

# %% [markdown]
# # Train the model using LogisticRegression

# %%
#Label encoding

le = LabelEncoder()
impact_df_copy = impact_df.copy()
impact_df_copy['counties'] = le.fit_transform(impact_df_copy['county_name'])
impact_df_copy.head()
# Out:
#   fire_started_date fire_extinguished_date  major_incident cause_description  \
# 0        2013-08-17             2013-09-06           False      Unidentified
# 1        2013-05-30             2013-06-08           False      Unidentified
# 2        2013-07-15             2013-07-30           False     Miscellaneous
# 3        2013-08-10             2013-08-30           False      Unidentified
# 4        2013-07-22             2013-09-24           False      Unidentified
#
#    archive_year  total_acres_burned  injuries        fire_name  \
# 0          2013              257314         0         Rim Fire
# 1          2013               30274         0  Powerhouse Fire
# 2          2013               27531         0    Mountain Fire
# 3          2013               27440         0    American Fire
# 4          2013               22992         0       Aspen Fire
#
#    structure_impacted minimum_temp(°C)  maximum_temp(°C) average_temp(°C)  \
# 0                   0             14.0              32.0             27.0
# 1                   0              9.0              34.0             27.0
# 2                   0             18.0              32.0             28.0
# 3                   0              6.0              26.0             20.0
# 4                   0             15.0              25.0             21.0
#
#    wind_speed(km/hr) air_pressure  precipitation(mm)  county_name   latitude  \
# 0                3.0       1015.0                0.0     Tuolumne     37.857
# 1               18.0       1010.0                0.0  Los Angeles  34.585595
# 2                7.0       1010.0                0.0    Riverside    33.7095
# 3                4.0       1015.0                0.0       Placer      39.12
# 4                2.0       1012.0                0.0       Fresno     37.279
#
#      longitude  counties
# 0     -120.086        53
# 1  -118.423176        17
# 2   -116.72885        32
# 3      -120.65        30
# 4     -119.318         9

# %%
#Extract month from fire_Start_date
impact_df_copy['fire_started_month'] = pd.DatetimeIndex(impact_df_copy['fire_started_date']).month
impact_df_copy.head()
# Out:
#   fire_started_date fire_extinguished_date  major_incident cause_description  \
# 0        2013-08-17             2013-09-06           False      Unidentified
# 1        2013-05-30             2013-06-08           False      Unidentified
# 2        2013-07-15             2013-07-30           False     Miscellaneous
# 3        2013-08-10             2013-08-30           False      Unidentified
# 4        2013-07-22             2013-09-24           False      Unidentified
#
#    archive_year  total_acres_burned  injuries        fire_name  \
# 0          2013              257314         0         Rim Fire
# 1          2013               30274         0  Powerhouse Fire
# 2          2013               27531         0    Mountain Fire
# 3          2013               27440         0    American Fire
# 4          2013               22992         0       Aspen Fire
#
#    structure_impacted minimum_temp(°C)  maximum_temp(°C) average_temp(°C)  \
# 0                   0             14.0              32.0             27.0
# 1                   0              9.0              34.0             27.0
# 2                   0             18.0              32.0             28.0
# 3                   0              6.0              26.0             20.0
# 4                   0             15.0              25.0             21.0
#
#    wind_speed(km/hr) air_pressure  precipitation(mm)  county_name   latitude  \
# 0                3.0       1015.0                0.0     Tuolumne     37.857
# 1               18.0       1010.0                0.0  Los Angeles  34.585595
# 2                7.0       1010.0                0.0    Riverside    33.7095
# 3                4.0       1015.0                0.0       Placer      39.12
# 4                2.0       1012.0                0.0       Fresno     37.279
#
#      longitude  counties  fire_started_month
# 0     -120.086        53                   8
# 1  -118.423176        17                   5
# 2   -116.72885        32                   7
# 3      -120.65        30                   8
# 4     -119.318         9                   7

# %%
# Set Major_fire variable depending on total_acres and maximum temperature - Major fire = 1, Not major fire = 0
def set_major_fire(acres,temp):
    if (acres >= 1000) and (temp >= 32):
        return 1
    else :
        return 0


impact_df_copy['major_fire'] = impact_df_copy.apply(lambda x: set_major_fire(x["total_acres_burned"],x["maximum_temp(°C)"]),axis=1)
impact_df_copy
# Out:
#      fire_started_date fire_extinguished_date  major_incident  \
# 0           2013-08-17             2013-09-06           False
# 1           2013-05-30             2013-06-08           False
# 2           2013-07-15             2013-07-30           False
# 3           2013-08-10             2013-08-30           False
# 4           2013-07-22             2013-09-24           False
# ...                ...                    ...             ...
# 1141        2018-10-07             2019-01-04           False
# 1142        2018-05-16             2019-01-04           False
# 1143        2018-02-18             2019-01-03           False
# 1144        2018-01-09             2019-01-03            True
# 1145        2019-04-09             2019-04-10           False
#
#      cause_description  archive_year  total_acres_burned  injuries  \
# 0         Unidentified          2013              257314         0
# 1         Unidentified          2013               30274         0
# 2        Miscellaneous          2013               27531         0
# 3         Unidentified          2013               27440         0
# 4         Unidentified          2013               22992         0
# ...                ...           ...                 ...       ...
# 1141      Unidentified          2018                4500         0
# 1142      Unidentified          2018                 293         0
# 1143      Unidentified          2018                  33         0
# 1144      Unidentified          2018                   0         0
# 1145      Unidentified          2019                  30         0
#
#                           fire_name  structure_impacted minimum_temp(°C)  ...  \
# 0                          Rim Fire                   0             14.0  ...
# 1                   Powerhouse Fire                   0              9.0  ...
# 2                     Mountain Fire                   0             18.0  ...
# 3                     American Fire                   0              6.0  ...
# 4                        Aspen Fire                   0             15.0  ...
# ...                             ...                 ...              ...  ...
# 1141                Branscombe Fire                   0             16.0  ...
# 1142                Twisselman Fire                   0              6.0  ...
# 1143                    Wilcox Fire                   0              8.0  ...
# 1144  Montecito Flooding / Mudflows                   0              9.0  ...
# 1145                   Girasol Fire                   0             18.0  ...
#
#       average_temp(°C) wind_speed(km/hr)  air_pressure precipitation(mm)  \
# 0                 27.0               3.0        1015.0               0.0
# 1                 27.0              18.0        1010.0               0.0
# 2                 28.0               7.0        1010.0               0.0
# 3                 20.0               4.0        1015.0               0.0
# 4                 21.0               2.0        1012.0               0.0
# ...                ...               ...           ...               ...
# 1141              22.0              26.0        1012.0               0.0
# 1142              17.0               8.0        1016.0               0.0
# 1143              15.0               7.0        1016.0               0.0
# 1144              11.0              30.0        1004.0               3.3
# 1145              26.0              12.0        1014.0               0.0
#
#         county_name   latitude    longitude counties  fire_started_month  \
# 0          Tuolumne     37.857     -120.086       53                   8
# 1       Los Angeles  34.585595  -118.423176       17                   5
# 2         Riverside    33.7095   -116.72885       32                   7
# 3            Placer      39.12      -120.65       30                   8
# 4            Fresno     37.279     -119.318        9                   7
# ...             ...        ...          ...      ...                 ...
# 1141         Solano      38.27    -121.9329       46                  10
# 1142           Kern    35.3429    -118.7299       13                   5
# 1143         Tulare    36.2201    -118.8005       52                   2
# 1144  Santa Barbara    34.6729    -120.0165       40                   1
# 1145      Riverside    33.7437    -115.9938       32                   4
#
#       major_fire
# 0              1
# 1              1
# 2              1
# 3              0
# 4              0
# ...          ...
# 1141           0
# 1142           0
# 1143           0
# 1144           0
# 1145           0
#
# [1146 rows x 21 columns]

# %%
#Check the total number of major and non-major fires
impact_df_copy["major_fire"].value_counts()
# Out:
# 0    1036
# 1     110
# Name: major_fire, dtype: int64

# %%
#Plot the count of the major and non major fire
sns.countplot(x='major_fire',data=impact_df_copy, palette='hls', hue="major_fire", dodge =False).set_title("Count of Target Variable : Major Fire")

plt.legend(labels=['Not major fire','Major fire'])
plt.savefig("Results/majorfire_class_count")

# %%
#Finding correlation between the features
impact_df_copy.corr()
# Out:
#                     major_incident  archive_year  total_acres_burned  \
# major_incident            1.000000     -0.118358            0.141636
# archive_year             -0.118358      1.000000            0.002258
# total_acres_burned        0.141636      0.002258            1.000000
# injuries                  0.347151     -0.173580            0.105933
# structure_impacted        0.176233      0.021836            0.344626
# maximum_temp(°C)          0.020516      0.061151            0.014282
# wind_speed(km/hr)         0.101530     -0.121714           -0.033389
# precipitation(mm)         0.101038      0.003590            0.002342
# counties                 -0.044578      0.018776            0.019985
# fire_started_month        0.053108      0.111350            0.054048
# major_fire                0.149852     -0.005498            0.272232
#
#                     injuries  structure_impacted  maximum_temp(°C)  \
# major_incident      0.347151            0.176233          0.020516
# archive_year       -0.173580            0.021836          0.061151
# total_acres_burned  0.105933            0.344626          0.014282
# injuries            1.000000            0.047631          0.003431
# structure_impacted  0.047631            1.000000         -0.001072
# maximum_temp(°C)    0.003431           -0.001072          1.000000
# wind_speed(km/hr)   0.018347           -0.001313         -0.235901
# precipitation(mm)   0.061825           -0.005345         -0.133177
# counties            0.029781           -0.009636          0.045451
# fire_started_month -0.009520            0.078709         -0.043495
# major_fire          0.131625            0.087163          0.301274
#
#                     wind_speed(km/hr)  precipitation(mm)  counties  \
# major_incident               0.101530           0.101038 -0.044578
# archive_year                -0.121714           0.003590  0.018776
# total_acres_burned          -0.033389           0.002342  0.019985
# injuries                     0.018347           0.061825  0.029781
# structure_impacted          -0.001313          -0.005345 -0.009636
# maximum_temp(°C)            -0.235901          -0.133177  0.045451
# wind_speed(km/hr)            1.000000           0.122639  0.005729
# precipitation(mm)            0.122639           1.000000 -0.048683
# counties                     0.005729          -0.048683  1.000000
# fire_started_month           0.023807          -0.017423  0.043423
# major_fire                  -0.056597          -0.008843  0.022989
#
#                     fire_started_month  major_fire
# major_incident                0.053108    0.149852
# archive_year                  0.111350   -0.005498
# total_acres_burned            0.054048    0.272232
# injuries                     -0.009520    0.131625
# structure_impacted            0.078709    0.087163
# maximum_temp(°C)             -0.043495    0.301274
# wind_speed(km/hr)             0.023807   -0.056597
# precipitation(mm)            -0.017423   -0.008843
# counties                      0.043423    0.022989
# fire_started_month            1.000000    0.012471
# major_fire                    0.012471    1.000000

# %%
#Plotting the correlation using heatmap
plt.figure(figsize=(16,5))
sns.heatmap(impact_df_copy.corr(), cmap="seismic", annot=True, linewidths=1, vmin=-1, vmax=1);
plt.savefig("Results/correlation_heatmap")

# %%
major_fire_count = impact_df_copy[impact_df_copy['major_fire'] == 1].groupby('fire_started_month')['major_fire'].count()
major_fire_count = major_fire_count.reset_index()
# Plot number of wildfire per month
sns.barplot(data=major_fire_count, x='fire_started_month', y='major_fire')
plt.xlabel('Months')
plt.ylabel('Number of Major fires')
plt.title('Number of Major Fires per Month(2013-2019)')
plt.savefig("Results/Major_fires_per_month")

# %%
#Scaling
scaled_data = StandardScaler()
Structure_Impacted_scaled = scaled_data.fit_transform(impact_df_copy[["structure_impacted"]])

impact_df_copy["structure_impacted_scaled"] = Structure_Impacted_scaled
impact_df_copy.head(15)
# Out:
#    fire_started_date fire_extinguished_date  major_incident  \
# 0         2013-08-17             2013-09-06           False
# 1         2013-05-30             2013-06-08           False
# 2         2013-07-15             2013-07-30           False
# 3         2013-08-10             2013-08-30           False
# 4         2013-07-22             2013-09-24           False
# 5         2013-08-07             2013-08-12            True
# 6         2013-07-31             2013-08-31           False
# 7         2013-08-10             2013-08-12           False
# 8         2013-08-23             2013-08-29            True
# 9         2013-09-09             2013-09-15            True
# 10        2013-07-06             2013-07-15            True
# 11        2013-05-01             2013-05-09            True
# 12        2013-05-15             2013-05-21            True
# 13        2013-11-22             2013-11-27            True
# 14        2013-05-01             2013-05-04            True
#
#           cause_description  archive_year  total_acres_burned  injuries  \
# 0              Unidentified          2013              257314         0
# 1              Unidentified          2013               30274         0
# 2             Miscellaneous          2013               27531         0
# 3              Unidentified          2013               27440         0
# 4              Unidentified          2013               22992         0
# 5              Unidentified          2013               20292        26
# 6              Unidentified          2013               14754         0
# 7              Unidentified          2013               12503         0
# 8             Miscellaneous          2013               11429         5
# 9                     Arson          2013                8073         6
# 10             Unidentified          2013                7055        12
# 11             Unidentified          2013                6965         6
# 12             Unidentified          2013                4346         4
# 13             Unidentified          2013                3505         6
# 14  Escaped Prescribed Burn          2013                3166         2
#
#                fire_name  structure_impacted minimum_temp(°C)  ...  \
# 0               Rim Fire                   0             14.0  ...
# 1        Powerhouse Fire                   0              9.0  ...
# 2          Mountain Fire                   0             18.0  ...
# 3          American Fire                   0              6.0  ...
# 4             Aspen Fire                   0             15.0  ...
# 5            Silver Fire                  48             15.0  ...
# 6   Salmon River Complex                   0              1.0  ...
# 7         Corral Complex                   0              4.0  ...
# 8              Deer Fire                   0             16.0  ...
# 9            Clover Fire                 211             17.0  ...
# 10          Chariot Fire                 158             19.0  ...
# 11          Panther Fire                   0              1.0  ...
# 12            Grand Fire                   0             13.0  ...
# 13           McCabe Fire                   1              7.0  ...
# 14           Summit Fire                   1             11.0  ...
#
#     wind_speed(km/hr) air_pressure  precipitation(mm)  county_name   latitude  \
# 0                 3.0       1015.0                0.0     Tuolumne     37.857
# 1                18.0       1010.0                0.0  Los Angeles  34.585595
# 2                 7.0       1010.0                0.0    Riverside    33.7095
# 3                 4.0       1015.0                0.0       Placer      39.12
# 4                 2.0       1012.0                0.0       Fresno     37.279
# 5                11.0       1014.0                0.0    Riverside   33.86157
# 6                 3.0       1020.0                0.0     Siskiyou      41.32
# 7                 3.0       1015.0                0.3     Humboldt     41.035
# 8                 5.0       1013.0                0.0       Tehama   40.04263
# 9                13.0       1012.0                0.0       Shasta  40.498332
# 10                8.0       1007.0                2.1    San Diego   32.95435
# 11               19.0       1022.0                0.0       Tehama  40.190062
# 12                6.0       1015.0                0.0         Kern    34.7861
# 13               26.0       1017.0                0.0       Sonoma    38.8167
# 14               11.0       1009.0                0.0    Riverside  34.288877
#
#       longitude counties fire_started_month  major_fire  \
# 0      -120.086       53                  8           1
# 1   -118.423176       17                  5           1
# 2    -116.72885       32                  7           1
# 3       -120.65       30                  8           0
# 4      -119.318        9                  7           0
# 5    -116.90427       32                  8           0
# 6      -123.176       45                  7           0
# 7      -123.488       11                  8           0
# 8    -121.85397       50                  8           1
# 9   -122.535496       43                  9           1
# 10   -116.47381       36                  7           0
# 11  -121.595555       50                  5           0
# 12    -118.9411       13                  5           0
# 13    -122.8498       47                 11           0
# 14  -116.941311       32                  5           0
#
#     structure_impacted_scaled
# 0                   -0.099634
# 1                   -0.099634
# 2                   -0.099634
# 3                   -0.099634
# 4                   -0.099634
# 5                    0.109138
# 6                   -0.099634
# 7                   -0.099634
# 8                   -0.099634
# 9                    0.818091
# 10                   0.587573
# 11                  -0.099634
# 12                  -0.099634
# 13                  -0.095285
# 14                  -0.095285
#
# [15 rows x 22 columns]

# %%
#Split data into target and features

y = impact_df_copy["major_fire"]
X = impact_df_copy[["fire_started_month","maximum_temp(°C)","wind_speed(km/hr)","precipitation(mm)"]]

# %%
print(f"Labels: {y[:10]}")
print(f"Data: {X[:10]}")
# Out:
# Labels: 0    1
# 1    1
# 2    1
# 3    0
# 4    0
# 5    0
# 6    0
# 7    0
# 8    1
# 9    1
# Name: major_fire, dtype: int64
# Data:    fire_started_month  maximum_temp(°C)  wind_speed(km/hr)  precipitation(mm)
# 0                   8              32.0                3.0                0.0
# 1                   5              34.0               18.0                0.0
# 2                   7              32.0                7.0                0.0
# 3                   8              26.0                4.0                0.0
# 4                   7              25.0                2.0                0.0
# 5                   8              27.0               11.0                0.0
# 6                   7              24.0                3.0                0.0
# 7                   8              21.0                3.0                0.3
# 8                   8              33.0                5.0                0.0
# 9                   9              37.0               13.0                0.0

# %%
#Split the dataset into training and testing data

X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    random_state=42, 
                                                    stratify=y)
X_train.shape
# Out:
# (859, 4)

# %%
#SMOTE resampling method for class imbalance

from imblearn.over_sampling import SMOTE
from collections import Counter
X_resampled, y_resampled = SMOTE(random_state=1,sampling_strategy='auto').fit_resample(
    X_train, y_train)
Counter(y_resampled)
# Out:
# Counter({0: 777, 1: 777})

# %%
#Train the Logistic Regression model 

classifier = LogisticRegression(solver='lbfgs',
                                max_iter=200,
                                random_state=1)

classifier.fit(X_resampled, y_resampled)
# Out:
# LogisticRegression(max_iter=200, random_state=1)

# %%
#calculate the predictions

y_pred = classifier.predict(X_test)

results = pd.DataFrame({"Prediction": y_pred, "Actual": y_test}).reset_index(drop=True)
results.head(10)
# Out:
#    Prediction  Actual
# 0           0       0
# 1           1       0
# 2           0       0
# 3           0       0
# 4           0       0
# 5           0       0
# 6           0       0
# 7           1       1
# 8           0       0
# 9           1       1

# %%
#Accuracy score
print(accuracy_score(y_test, y_pred))
# Out:
# 0.710801393728223

# %%
# Display the confusion matrix
matrix = confusion_matrix(y_test, y_pred)
print(matrix)
# Out:
# [[181  78]
#  [  5  23]]

# %%
# Display the true positive, false negative, false positive, true negative for major fire
tn, fp, fn, tp= confusion_matrix(y_test, y_pred).ravel()
tn, fp, fn, tp
# Out:
# (181, 78, 5, 23)

# %%
# Print the classification_report.
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.70      0.81       259
#            1       0.23      0.82      0.36        28
#
#     accuracy                           0.71       287
#    macro avg       0.60      0.76      0.59       287
# weighted avg       0.90      0.71      0.77       287

# %%
# Plot the confusion matrix.

plot_confusion_matrix(classifier, X_test,y_test)
plt.savefig("Results/confusion_matrix")

# %%
#Plot the S curve for max temp

plt.figure(figsize=(10,5))
sns.regplot(x=impact_df_copy["maximum_temp(°C)"], y=impact_df_copy["major_fire"], logistic=True).set_title("Max_Temp Log Odds Linear Plot")
plt.savefig("Results/S-curve")

# %%
#Plot the S curve for windspeed

plt.figure(figsize=(10,5))
sns.regplot(x=impact_df_copy["wind_speed(km/hr)"], y=impact_df_copy["major_fire"], logistic=True).set_title("Wind_Speed Log Odds Linear Plot")
# Out:
# Text(0.5, 1.0, 'Wind_Speed Log Odds Linear Plot')

# %%
#Plot the S curve for precipitation

plt.figure(figsize=(10,5))
sns.regplot(x=impact_df_copy["precipitation(mm)"], y=impact_df_copy["major_fire"], logistic=True).set_title("Precipitation Log Odds Linear Plot")
# Out:
# Text(0.5, 1.0, 'Precipitation Log Odds Linear Plot')

# %%
#Plot the S curve for fire start month

plt.figure(figsize=(10,5))
sns.regplot(x=impact_df_copy["fire_started_month"], y=impact_df_copy["major_fire"], logistic=True).set_title("Fire start month Log Odds Linear Plot")
# Out:
# Text(0.5, 1.0, 'Fire start month Log Odds Linear Plot')
